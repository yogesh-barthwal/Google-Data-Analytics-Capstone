# %% [markdown]
# #### Python Pandas has been used to combine all the excel files into one single dataframe.
# #### Some preprocessing steps will also be done via python only

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob # To concatenate all the csv files and create a single dataframe

# %%
folder_path = r"Y:\Data\Data Analytics by Google Capstone\Cyclistic Data\CSV Files"
csv_files = glob.glob(folder_path + r"/*.csv" )  # Returns a list

# %%
type(csv_files)
# Out:
# list

# %%
df_list = (pd.read_csv(file) for file in csv_files)

# %%
df =pd.concat( df_list,ignore_index=True)

# %%
df
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        954144C2F67B1932   classic_bike  2022-07-05 08:12:47
# 1        292E027607D218B6   classic_bike  2022-07-26 12:53:38
# 2        57765852588AD6E0   classic_bike  2022-07-03 13:58:49
# 3        B5B6BE44314590E6   classic_bike  2022-07-31 17:44:21
# 4        A4C331F2A00E79E0   classic_bike  2022-07-13 19:49:06
# ...                   ...            ...                  ...
# 5779439  D7BBF4BCBB72DA32   classic_bike     30-06-2023 12:58
# 5779440  9A1685F9A39646CA  electric_bike     29-06-2023 19:56
# 5779441  CD4CC5A60881C7AF  electric_bike     25-06-2023 00:27
# 5779442  FF6594685CFE2056  electric_bike     24-06-2023 21:26
# 5779443  66EF9F3C318208B9   classic_bike     24-06-2023 21:30
#
#                     ended_at          start_station_name start_station_id  \
# 0        2022-07-05 08:24:32  Ashland Ave & Blackhawk St            13224
# 1        2022-07-26 12:55:31  Buckingham Fountain (Temp)            15541
# 2        2022-07-03 14:06:32  Buckingham Fountain (Temp)            15541
# 3        2022-07-31 18:42:50  Buckingham Fountain (Temp)            15541
# 4        2022-07-13 20:15:24      Wabash Ave & Grand Ave     TA1307000117
# ...                      ...                         ...              ...
# 5779439     30-06-2023 13:41    Fairbanks Ct & Grand Ave     TA1305000003
# 5779440     29-06-2023 20:09    Fairbanks Ct & Grand Ave     TA1305000003
# 5779441     25-06-2023 00:39      Clark St & Lincoln Ave            13179
# 5779442     24-06-2023 21:28    Fairbanks Ct & Grand Ave     TA1305000003
# 5779443     25-06-2023 22:30    Fairbanks Ct & Grand Ave     TA1305000003
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0              Kingsbury St & Kinzie St   KA1503000043  41.907066 -87.667252
# 1                 Michigan Ave & 8th St            623  41.869621 -87.623981
# 2                 Michigan Ave & 8th St            623  41.869621 -87.623981
# 3                Woodlawn Ave & 55th St   TA1307000164  41.869621 -87.623981
# 4        Sheffield Ave & Wellington Ave   TA1307000052  41.891466 -87.626761
# ...                                 ...            ...        ...        ...
# 5779439  California Ave & Milwaukee Ave          13084  41.891847 -87.620580
# 5779440                             NaN            NaN  41.891970 -87.620198
# 5779441                             NaN            NaN  41.915745 -87.634604
# 5779442                             NaN            NaN  41.891725 -87.620607
# 5779443                             NaN            NaN  41.891847 -87.620580
#
#            end_lat    end_lng member_casual
# 0        41.889177 -87.638506        member
# 1        41.872773 -87.623981        casual
# 2        41.872773 -87.623981        casual
# 3        41.795264 -87.596471        casual
# 4        41.936253 -87.652662        member
# ...            ...        ...           ...
# 5779439  41.922695 -87.697153        casual
# 5779440  41.890000 -87.610000        casual
# 5779441  41.920000 -87.650000        casual
# 5779442  41.890000 -87.620000        casual
# 5779443        NaN        NaN        casual
#
# [5779444 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5779444 entries, 0 to 5779443
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 573.2+ MB

# %% [markdown]
# Dropping the ride_id as it will not be of any help for visualizations

# %%
df.drop('ride_id', inplace=True, axis=1)

# %%
df.isnull().sum()
# Out:
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    857860
# start_station_id      857992
# end_station_name      915655
# end_station_id        915796
# start_lat                  0
# start_lng                  0
# end_lat                 5795
# end_lng                 5795
# member_casual              0
# dtype: int64

# %% [markdown]
# There are a lot of null values in the following features-
# - start_station_name    857860
# - start_station_id      857992
# - end_station_name      915655
# - end_station_id        915796

# %% [markdown]
# As can be seen, there are observations where start_station_name is not null but start_station_id is null.
#
# There are observations in the dataset where the same start_station names appear and there are station_id values present agaisnt it.
#
# Thus the null values can be replaced by those station ids

# %%
# Creating a function for the purpose
def names_to_id(id,naam):
    # Unique value of start staion names where station names exist but station ids do not
    name_replacements = df[(naam.notnull() ) & (id.isnull())][naam.name].unique() # naam.name to get the name of the column as id represents the entire series
    names_id = df[(naam.isin(name_replacements)) & id.notnull()][[id.name,naam.name]].drop_duplicates()
    names_id_dict = dict(zip(names_id[id.name],names_id[naam.name]))
    #print(names_id_dict)
    return df[naam.name].map(names_id_dict).fillna(df[id.name])

# %%
df['start_station_id']= names_to_id(df['start_station_id'],df['start_station_name'])

# %%
df['end_station_id']= names_to_id(df['end_station_id'],df['end_station_name'])

# %%
df.isnull().sum()
# Out:
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    857860
# start_station_id      857992
# end_station_name      915655
# end_station_id        915796
# start_lat                  0
# start_lng                  0
# end_lat                 5795
# end_lng                 5795
# member_casual              0
# dtype: int64

# %% [markdown]
# Now there are as many null values against the start_station_id as are against start_station_name

# %% [markdown]
# Performing similar opertaion for end stations as well

# %%
df.isnull().sum()
# Out:
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    857860
# start_station_id      857992
# end_station_name      915655
# end_station_id        915796
# start_lat                  0
# start_lng                  0
# end_lat                 5795
# end_lng                 5795
# member_casual              0
# dtype: int64

# %% [markdown]
# Again there are as many null values against the end_station_id as are against end_station_name

# %% [markdown]
# Trying to impute the null values by checking if latitude and longitude values corresponding to certain observations are same, then their station_id and station_name (both start and end) will also be same.

# %%
df[df['start_station_name'].isnull()]
# Out:
#          rideable_type           started_at             ended_at  \
# 1719     electric_bike  2022-07-04 15:04:26  2022-07-04 15:32:38
# 1720     electric_bike  2022-07-12 14:43:51  2022-07-12 14:49:28
# 1721     electric_bike  2022-07-10 11:37:27  2022-07-10 11:40:03
# 2988     electric_bike  2022-07-23 07:41:53  2022-07-23 08:02:14
# 2989     electric_bike  2022-07-30 07:26:54  2022-07-30 07:30:36
# ...                ...                  ...                  ...
# 5774141  electric_bike     19-06-2023 21:55     19-06-2023 22:10
# 5774150  electric_bike     08-06-2023 00:02     08-06-2023 00:12
# 5774151  electric_bike     07-06-2023 20:35     07-06-2023 20:59
# 5774152  electric_bike     08-06-2023 17:22     08-06-2023 17:27
# 5774153  electric_bike     13-06-2023 11:05     13-06-2023 11:07
#
#         start_station_name start_station_id  \
# 1719                   NaN              NaN
# 1720                   NaN              NaN
# 1721                   NaN              NaN
# 2988                   NaN              NaN
# 2989                   NaN              NaN
# ...                    ...              ...
# 5774141                NaN              NaN
# 5774150                NaN              NaN
# 5774151                NaN              NaN
# 5774152                NaN              NaN
# 5774153                NaN              NaN
#
#                                  end_station_name end_station_id  start_lat  \
# 1719                   Ashland Ave & Blackhawk St          13224      41.95
# 1720                 Cornell Ave & Hyde Park Blvd   KA1503000007      41.80
# 1721                 Cornell Ave & Hyde Park Blvd   KA1503000007      41.80
# 2988                        Brandon Ave & 91st St            847      41.74
# 2989     Public Rack - Chase Ave & Touhy Ave - NE            482      42.02
# ...                                           ...            ...        ...
# 5774141                                       NaN            NaN      41.97
# 5774150                                       NaN            NaN      41.93
# 5774151                                       NaN            NaN      41.85
# 5774152                                       NaN            NaN      41.94
# 5774153                                       NaN            NaN      41.89
#
#          start_lng    end_lat    end_lng member_casual
# 1719        -87.64  41.907066 -87.667252        member
# 1720        -87.59  41.802406 -87.586924        member
# 1721        -87.59  41.802406 -87.586924        member
# 2988        -87.55  41.730000 -87.550000        member
# 2989        -87.69  42.010000 -87.690000        member
# ...            ...        ...        ...           ...
# 5774141     -87.65  41.940000 -87.660000        casual
# 5774150     -87.69  41.930000 -87.710000        casual
# 5774151     -87.61  41.880000 -87.650000        casual
# 5774152     -87.67  41.940000 -87.650000        casual
# 5774153     -87.63  41.890000 -87.630000        casual
#
# [857860 rows x 12 columns]

# %%
df[(df['end_lat']== 41.95) & (df['end_lng']== -87.64) & (df['end_station_id'].notnull())]
# Out:
# Empty DataFrame
# Columns: [rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual]
# Index: []

# %% [markdown]
# As can be seen, there are no such observations where latitude and longitude values are same and corresponding station id and station names are not null
#
# Thus this method of imputation cannot be implemented

# %% [markdown]
# We can impute by using mode- but this will create a bias as there are a lot of null values and imputing all of those by a single value will create a bias

# %%
df['start_station_name'].mode().values[0]
# Out:
# 'Streeter Dr & Grand Ave'

# %% [markdown]
# Trying to impute by choosing values randomly

# %%
# Function for random imputation
def random_imputation(x): # x is the dataframe column containing null values
    null_num = x.isnull().sum() # No. of null values
    random_values = x.dropna().sample(null_num,random_state=4) # Creating a series that contains values taken randomly from start_station_id of the df
    # print(random_values)
    random_values.index = df[x.isnull()].index # Assigning the same indices to this series containing random values as are the indices of null values in the column of df
    return x.fillna(random_values)

# %%
df['start_station_id'] = random_imputation(df['start_station_id']) # The null values of the start_station_id of the dataframe are replaced by the values of newly created df

# %%
df['end_station_id'] = random_imputation(df['end_station_id']) # The null values of the end_station_id of the dataframe are replaced by the values of newly created df

# %%
df.isnull().sum()
# Out:
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    857860
# start_station_id           0
# end_station_name      915655
# end_station_id             0
# start_lat                  0
# start_lng                  0
# end_lat                 5795
# end_lng                 5795
# member_casual              0
# dtype: int64

# %% [markdown]
# Imputing station_names(start and end) by checking values of station_id(start and end)

# %%
# Creating a function for the purpose
def id_to_names(id,naam):
    #print(id.name)
    id_replacements = df[(id.notnull()) & (naam.isnull())][id.name].unique() # id.name to get the name of the column as id represents the entire series
    id_names = df[(id.isin(id_replacements)) & naam.notnull()][[id.name,naam.name]].drop_duplicates()
    #print(id_names)
    id_names_dict = dict(zip(id_names[id.name],id_names[naam.name]))
    return df[id.name].map(id_names_dict).fillna(df[naam.name])

# %%
df['start_station_name'] = id_to_names(df['start_station_id'], df['start_station_name'])

# %%
df['end_station_name'] = id_to_names(df['end_station_id'], df['end_station_name'])

# %%
df.isnull().sum()
# Out:
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name       0
# start_station_id         0
# end_station_name         0
# end_station_id           0
# start_lat                0
# start_lng                0
# end_lat               5795
# end_lng               5795
# member_casual            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name       0
# start_station_id         0
# end_station_name         0
# end_station_id           0
# start_lat                0
# start_lng                0
# end_lat               5795
# end_lng               5795
# member_casual            0
# dtype: int64

# %% [markdown]
# Now only end_lat and end_lang values have null values in them

# %%
null_lat_long = df[(df['end_lat'].isnull()) & (df['end_lng'].isnull())]['end_station_id'].unique()
len(null_lat_long)
# Out:
# 591

# %%
station_to_lat_lng = df[df['end_station_id'].isin(null_lat_long) & df['end_lat'].notnull()][['end_station_id','end_lat', 'end_lng']].drop_duplicates()
station_to_lat_lng
# Out:
#         end_station_id    end_lat    end_lng
# 0         KA1503000043  41.889177 -87.638506
# 1                  623  41.872773 -87.623981
# 3         TA1307000164  41.795264 -87.596471
# 4         TA1307000052  41.936253 -87.652662
# 5               WL-008  41.867118 -87.641088
# ...                ...        ...        ...
# 5779240          13258  41.960000 -87.770000
# 5779252          18067  41.910000 -87.740000
# ...                ...                  ...                  ...
# 5779439   classic_bike     30-06-2023 12:58     30-06-2023 13:41
# 5779440  electric_bike     29-06-2023 19:56     29-06-2023 20:09
# 5779441  electric_bike     25-06-2023 00:27     25-06-2023 00:39
# 5779442  electric_bike     24-06-2023 21:26     24-06-2023 21:28
# 5779443   classic_bike     24-06-2023 21:30     25-06-2023 22:30
#
#                  start_station_name start_station_id  \
# 0        Ashland Ave & Blackhawk St            13224
# 1               Buckingham Fountain            15541
# 2               Buckingham Fountain            15541
# 3               Buckingham Fountain            15541
# 4        Elizabeth St & Randolph St     TA1307000117
# ...                             ...              ...
# 5779439  Elizabeth St & Randolph St     TA1305000003
# 5779440  Elizabeth St & Randolph St     TA1305000003
# 5779441      Clark St & Lincoln Ave            13179
# 5779442  Elizabeth St & Randolph St     TA1305000003
# 5779443  Elizabeth St & Randolph St     TA1305000003
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0              Kingsbury St & Kinzie St   KA1503000043  41.907066 -87.667252
# 1            Elizabeth St & Randolph St            623  41.869621 -87.623981
# 2            Elizabeth St & Randolph St            623  41.869621 -87.623981
# 3            Elizabeth St & Randolph St   TA1307000164  41.869621 -87.623981
# 4        Sheffield Ave & Wellington Ave   TA1307000052  41.891466 -87.626761
# ...                                 ...            ...        ...        ...
# 5779439      Elizabeth St & Randolph St          13084  41.891847 -87.620580
# 5779440          Kedzie Ave & Palmer Ct          13292  41.891970 -87.620198
# 5779441      Elizabeth St & Randolph St         LF-005  41.915745 -87.634604
# 5779442       LaSalle St & Jackson Blvd   TA1309000004  41.891725 -87.620607
# 5779443      Elizabeth St & Randolph St          13008  41.891847 -87.620580
#
#          end_lat  end_lng member_casual
# 0          41.82   -87.63        member
# 1          41.90   -87.61        casual
# 2          41.90   -87.61        casual
# 3          41.83   -87.64        casual
# 4          41.75   -87.65        member
# ...          ...      ...           ...
# 5779439    41.79   -87.77        casual
# 5779440    41.85   -87.69        casual
# 5779441    41.98   -87.84        casual
# 5779442    41.98   -87.76        casual
# 5779443    41.71   -87.62        casual
#
# [5779444 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# dtype: int64

# %% [markdown]
# Thus all the null values have been imputed

# %% [markdown]
# Calculating ride length as end time -start time

# %%
df['ended_at'] = pd.to_datetime(df['ended_at']).astype('datetime64')

# %%
df['started_at'] = pd.to_datetime(df['started_at']).astype('datetime64')

# %%
df['ride_length'] = df['ended_at']- df['started_at']

# %% [markdown]
# Checking for day of the week on which a particular ride took place

# %%
df['day_of_week'] = df['started_at'].dt.dayofweek + 1 # 1 is added to make sunday as 1

# %% [markdown]
# Checking for monthn in which the ride took place

# %%
df['month'] = df['started_at'].dt.month

# id of stations would not be required now for visualizations. Thus dropping start_station_id and end_station_id

# %%
df.drop(['start_station_id','end_station_id'], axis=1, inplace = True)

# %%
df
# Out:
#          rideable_type          started_at            ended_at  \
# 0         classic_bike 2022-07-05 08:12:47 2022-07-05 08:24:32
# 1         classic_bike 2022-07-26 12:53:38 2022-07-26 12:55:31
# 2         classic_bike 2022-07-03 13:58:49 2022-07-03 14:06:32
# 3         classic_bike 2022-07-31 17:44:21 2022-07-31 18:42:50
# 4         classic_bike 2022-07-13 19:49:06 2022-07-13 20:15:24
# ...                ...                 ...                 ...
# 5779439   classic_bike 2023-06-30 12:58:00 2023-06-30 13:41:00
# 5779440  electric_bike 2023-06-29 19:56:00 2023-06-29 20:09:00
# 5779441  electric_bike 2023-06-25 00:27:00 2023-06-25 00:39:00
# 5779442  electric_bike 2023-06-24 21:26:00 2023-06-24 21:28:00
# 5779443   classic_bike 2023-06-24 21:30:00 2023-06-25 22:30:00
#
#                  start_station_name                end_station_name  \
# 0        Ashland Ave & Blackhawk St        Kingsbury St & Kinzie St
# 1               Buckingham Fountain      Elizabeth St & Randolph St
# 2               Buckingham Fountain      Elizabeth St & Randolph St
# 3               Buckingham Fountain      Elizabeth St & Randolph St
# 4        Elizabeth St & Randolph St  Sheffield Ave & Wellington Ave
# ...                             ...                             ...
# 5779439  Elizabeth St & Randolph St      Elizabeth St & Randolph St
# 5779440  Elizabeth St & Randolph St          Kedzie Ave & Palmer Ct
# 5779441      Clark St & Lincoln Ave      Elizabeth St & Randolph St
# 5779442  Elizabeth St & Randolph St       LaSalle St & Jackson Blvd
# 5779443  Elizabeth St & Randolph St      Elizabeth St & Randolph St
#
#          start_lat  start_lng  end_lat  end_lng member_casual     ride_length  \
# 0        41.907066 -87.667252    41.82   -87.63        member 0 days 00:11:45
# 1        41.869621 -87.623981    41.90   -87.61        casual 0 days 00:01:53
# 2        41.869621 -87.623981    41.90   -87.61        casual 0 days 00:07:43
# 3        41.869621 -87.623981    41.83   -87.64        casual 0 days 00:58:29
# 4        41.891466 -87.626761    41.75   -87.65        member 0 days 00:26:18
# ...            ...        ...      ...      ...           ...             ...
# 5779439  41.891847 -87.620580    41.79   -87.77        casual 0 days 00:43:00
# 5779440  41.891970 -87.620198    41.85   -87.69        casual 0 days 00:13:00
# 5779441  41.915745 -87.634604    41.98   -87.84        casual 0 days 00:12:00
# 5779442  41.891725 -87.620607    41.98   -87.76        casual 0 days 00:02:00
# 5779443  41.891847 -87.620580    41.71   -87.62        casual 1 days 01:00:00
#
#          day_of_week  month
# 0                  2      7
# 1                  2      7
# 2                  7      7
# 3                  7      7
# 4                  3      7
# ...              ...    ...
# 5779439            5      6
# 5779440            4      6
# 5779441            7      6
# 5779442            6      6
# 5779443            6      6
#
# [5779444 rows x 13 columns]

# %% [markdown]
# Saving this df as a csv file

# %%
df.to_csv('Combined Cyclist Data')
